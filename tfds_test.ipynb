# %%
import tensorflow as tf
import tensorflow_datasets as tfds
# Out:
# 2021-11-10 15:40:40.734409: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.11.0
# 2021-11-10 15:40:41.957203: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libnvinfer.so.7
# 2021-11-10 15:40:41.958996: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libnvinfer_plugin.so.7

# %%
ds = tfds.load('coco/2017', split='train', shuffle_files=True)

# %%
import cv2
import matplotlib.pyplot as plt

ds2 = ds = ds.take(5)
for x in ds2:
    # print(x['image'].numpy())
#     img = cv2.imread(x['image'].numpy())
    print(x)
   #  objs = x['objects']
   #  print(x['image/id'])
   # # print(objs['image/id'])
   #  # for z,v in objs.items():
   #  #     print(z,v)
   #  plt.figure()
   #  plt.imshow(x['image'].numpy())
# Out:
# {'image': <tf.Tensor: shape=(229, 640, 3), dtype=uint8, numpy=
# array([[[155, 198, 251],
#         [156, 199, 252],
#         [154, 197, 250],
#         ...,
#         [187, 220, 255],
#         [183, 217, 252],
#         [182, 218, 250]],
#
#        [[152, 198, 250],
#         [153, 199, 251],
#         [155, 198, 249],
#         ...,
#         [186, 219, 252],
#         [186, 221, 253],
#         [184, 220, 252]],
#
#        [[157, 203, 255],
#         [157, 203, 253],
#         [154, 200, 250],
#         ...,
#         [185, 215, 249],
#         [187, 220, 253],
#         [184, 219, 251]],
#
#        ...,
#
#        [[ 47,  65,  87],
#         [ 55,  71,  96],
#         [ 57,  73,  99],
#         ...,
#         [ 54,  72,  96],
#         [ 59,  77, 101],
#         [ 52,  70,  94]],
#
#        [[ 51,  67,  90],
#         [ 50,  66,  91],
#         [ 58,  74, 100],
#         ...,
#         [ 44,  61,  87],
#         [ 57,  75,  99],
#         [ 55,  73,  97]],
#
# ...
